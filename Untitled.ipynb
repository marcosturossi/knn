# %%
import pandas as pd
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
column_names = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width', 'class']
df = pd.read_csv("iris.data", names=("sepal_length", "sepal width in cm", "petal length", "petal width", "class"))

# %%
# Passo 2: Calcular estatísticas descritivas
# Média, desvio padrão e moda de cada variável em geral
print("Estatísticas gerais:")
print(df.describe())
# Out:
# Estatísticas gerais:
#        sepal_length  sepal width in cm  petal length  petal width
# count    150.000000         150.000000    150.000000   150.000000
# mean       5.843333           3.054000      3.758667     1.198667
# std        0.828066           0.433594      1.764420     0.763161
# min        4.300000           2.000000      1.000000     0.100000
# 25%        5.100000           2.800000      1.600000     0.300000
# 50%        5.800000           3.000000      4.350000     1.300000
# 75%        6.400000           3.300000      5.100000     1.800000
# max        7.900000           4.400000      6.900000     2.500000

# %%
# Média, desvio padrão e moda de cada variável por categoria
print("\nEstatísticas por categoria:")
print(df.groupby('class').describe())
# Out:
# Estatísticas por categoria:
#                 sepal_length                                              \
#                        count   mean       std  min    25%  50%  75%  max
# class
# Iris-setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#                 sepal width in cm         ... petal length      petal width  \
#                             count   mean  ...          75%  max       count
# class                                     ...
# Iris-setosa                  50.0  3.418  ...        1.575  1.9        50.0
# Iris-versicolor              50.0  2.770  ...        4.600  5.1        50.0
# Iris-virginica               50.0  2.974  ...        5.875  6.9        50.0
#
#
#                   mean       std  min  25%  50%  75%  max
# class
# Iris-setosa      0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# Iris-versicolor  1.326  0.197753  1.0  1.2  1.3  1.5  1.8
# Iris-virginica   2.026  0.274650  1.4  1.8  2.0  2.3  2.5
#
# [3 rows x 32 columns]

# %%
print(df.head())
print(df.columns)
# Out:
#    sepal_length  sepal width in cm  petal length  petal width        class
# 0           5.1                3.5           1.4          0.2  Iris-setosa
# 1           4.9                3.0           1.4          0.2  Iris-setosa
# 2           4.7                3.2           1.3          0.2  Iris-setosa
# 3           4.6                3.1           1.5          0.2  Iris-setosa
# 4           5.0                3.6           1.4          0.2  Iris-setosa
# Index(['sepal_length', 'sepal width in cm', 'petal length', 'petal width',
#        'class'],
#       dtype='object')

# %%
plt.scatter(df[df['class'] == 'Iris-setosa']['sepal_length'], df[df['class'] == 'Iris-setosa']['sepal_width'], label='Iris-setosa')
plt.scatter(df[df['class'] == 'Iris-versicolor']['sepal_length'], df[df['class'] == 'Iris-versicolor']['sepal_width'], label='Iris-versicolor')
plt.scatter(df[df['class'] == 'Iris-virginica']['sepal_length'], df[df['class'] == 'Iris-virginica']['sepal_width'], label='Iris-virginica')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sepal_width'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 plt.scatter(df[df['class'] == 'Iris-setosa']['sepal_length'], df[df['class'] == 'Iris-setosa']['sepal_width'], label='Iris-setosa')
#       2 plt.scatter(df[df['class'] == 'Iris-versicolor']['sepal_length'], df[df['class'] == 'Iris-versicolor']['sepal_width'], label='Iris-versicolor')
#       3 plt.scatter(df[df['class'] == 'Iris-virginica']['sepal_length'], df[df['class'] == 'Iris-virginica']['sepal_width'], label='Iris-virginica')
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'sepal_width'

# %%
df1 = df.loc[:, df.columns != "class"]

# %%
df1.std()
# Out:
# sepal_length         0.828066
# sepal width in cm    0.433594
# petal length         1.764420
# petal width          0.763161
# dtype: float64

# %%
df1.mean()
# Out:
# sepal_length         5.843333
# sepal width in cm    3.054000
# petal length         3.758667
# petal width          1.198667
# dtype: float64

# %%
df1.mode()
# Out:
#    sepal_length  sepal width in cm  petal length  petal width
# 0           5.0                3.0           1.5          0.2

# %%
# Média, desvio padrão e moda de cada variável por categoria
print("\nEstatísticas por categoria:")
print(df.groupby('class').describe())
# Out:
# Estatísticas por categoria:
#                 sepal_length                                              \
#                        count   mean       std  min    25%  50%  75%  max
# class
# Iris-setosa             50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8
# Iris-versicolor         50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0
# Iris-virginica          50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9
#
#                 sepal width in cm         ... petal length      petal width  \
#                             count   mean  ...          75%  max       count
# class                                     ...
# Iris-setosa                  50.0  3.418  ...        1.575  1.9        50.0
# Iris-versicolor              50.0  2.770  ...        4.600  5.1        50.0
# Iris-virginica               50.0  2.974  ...        5.875  6.9        50.0
#
#
#                   mean       std  min  25%  50%  75%  max
# class
# Iris-setosa      0.244  0.107210  0.1  0.2  0.2  0.3  0.6
# Iris-versicolor  1.326  0.197753  1.0  1.2  1.3  1.5  1.8
# Iris-virginica   2.026  0.274650  1.4  1.8  2.0  2.3  2.5
#
# [3 rows x 32 columns]

# %%
df_class1 = df.loc[df["class"] == "Iris-setosa"]

# %%
df_class1
# Out:
#     sepal_length  sepal width in cm  petal length  petal width        class
# 0            5.1                3.5           1.4          0.2  Iris-setosa
# 1            4.9                3.0           1.4          0.2  Iris-setosa
# 2            4.7                3.2           1.3          0.2  Iris-setosa
# 3            4.6                3.1           1.5          0.2  Iris-setosa
# 4            5.0                3.6           1.4          0.2  Iris-setosa
# 5            5.4                3.9           1.7          0.4  Iris-setosa
# 6            4.6                3.4           1.4          0.3  Iris-setosa
# 7            5.0                3.4           1.5          0.2  Iris-setosa
# 8            4.4                2.9           1.4          0.2  Iris-setosa
# 9            4.9                3.1           1.5          0.1  Iris-setosa
# 10           5.4                3.7           1.5          0.2  Iris-setosa
# 11           4.8                3.4           1.6          0.2  Iris-setosa
# 12           4.8                3.0           1.4          0.1  Iris-setosa
# 13           4.3                3.0           1.1          0.1  Iris-setosa
# 14           5.8                4.0           1.2          0.2  Iris-setosa
# 15           5.7                4.4           1.5          0.4  Iris-setosa
# 16           5.4                3.9           1.3          0.4  Iris-setosa
# 17           5.1                3.5           1.4          0.3  Iris-setosa
# 18           5.7                3.8           1.7          0.3  Iris-setosa
# 19           5.1                3.8           1.5          0.3  Iris-setosa
# 20           5.4                3.4           1.7          0.2  Iris-setosa
# 21           5.1                3.7           1.5          0.4  Iris-setosa
# 22           4.6                3.6           1.0          0.2  Iris-setosa
# 23           5.1                3.3           1.7          0.5  Iris-setosa
# 24           4.8                3.4           1.9          0.2  Iris-setosa
# 25           5.0                3.0           1.6          0.2  Iris-setosa
# 26           5.0                3.4           1.6          0.4  Iris-setosa
# 27           5.2                3.5           1.5          0.2  Iris-setosa
# 28           5.2                3.4           1.4          0.2  Iris-setosa
# 29           4.7                3.2           1.6          0.2  Iris-setosa
# 30           4.8                3.1           1.6          0.2  Iris-setosa
# 31           5.4                3.4           1.5          0.4  Iris-setosa
# 32           5.2                4.1           1.5          0.1  Iris-setosa
# 33           5.5                4.2           1.4          0.2  Iris-setosa
# 34           4.9                3.1           1.5          0.1  Iris-setosa
# 35           5.0                3.2           1.2          0.2  Iris-setosa
# 36           5.5                3.5           1.3          0.2  Iris-setosa
# 37           4.9                3.1           1.5          0.1  Iris-setosa
# 38           4.4                3.0           1.3          0.2  Iris-setosa
# 39           5.1                3.4           1.5          0.2  Iris-setosa
# 40           5.0                3.5           1.3          0.3  Iris-setosa
# 41           4.5                2.3           1.3          0.3  Iris-setosa
# 42           4.4                3.2           1.3          0.2  Iris-setosa
# 43           5.0                3.5           1.6          0.6  Iris-setosa
# 44           5.1                3.8           1.9          0.4  Iris-setosa
# 45           4.8                3.0           1.4          0.3  Iris-setosa
# 46           5.1                3.8           1.6          0.2  Iris-setosa
# 47           4.6                3.2           1.4          0.2  Iris-setosa
# 48           5.3                3.7           1.5          0.2  Iris-setosa
# 49           5.0                3.3           1.4          0.2  Iris-setosa

# %%
df_class1 = df_class1.loc[:, df_class1.columns != "class"]

# %%
df_class1
# Out:
#     sepal_length  sepal width in cm  petal length  petal width
# 0            5.1                3.5           1.4          0.2
# 1            4.9                3.0           1.4          0.2
# 2            4.7                3.2           1.3          0.2
# 3            4.6                3.1           1.5          0.2
# 4            5.0                3.6           1.4          0.2
# 5            5.4                3.9           1.7          0.4
# 6            4.6                3.4           1.4          0.3
# 7            5.0                3.4           1.5          0.2
# 8            4.4                2.9           1.4          0.2
# 9            4.9                3.1           1.5          0.1
# 10           5.4                3.7           1.5          0.2
# 11           4.8                3.4           1.6          0.2
# 12           4.8                3.0           1.4          0.1
# 13           4.3                3.0           1.1          0.1
# 14           5.8                4.0           1.2          0.2
# 15           5.7                4.4           1.5          0.4
# 16           5.4                3.9           1.3          0.4
# 17           5.1                3.5           1.4          0.3
# 18           5.7                3.8           1.7          0.3
# 19           5.1                3.8           1.5          0.3
# 20           5.4                3.4           1.7          0.2
# 21           5.1                3.7           1.5          0.4
# 22           4.6                3.6           1.0          0.2
# 23           5.1                3.3           1.7          0.5
# 24           4.8                3.4           1.9          0.2
# 25           5.0                3.0           1.6          0.2
# 26           5.0                3.4           1.6          0.4
# 27           5.2                3.5           1.5          0.2
# 28           5.2                3.4           1.4          0.2
# 29           4.7                3.2           1.6          0.2
# 30           4.8                3.1           1.6          0.2
# 31           5.4                3.4           1.5          0.4
# 32           5.2                4.1           1.5          0.1
# 33           5.5                4.2           1.4          0.2
# 34           4.9                3.1           1.5          0.1
# 35           5.0                3.2           1.2          0.2
# 36           5.5                3.5           1.3          0.2
# 37           4.9                3.1           1.5          0.1
# 38           4.4                3.0           1.3          0.2
# 39           5.1                3.4           1.5          0.2
# 40           5.0                3.5           1.3          0.3
# 41           4.5                2.3           1.3          0.3
# 42           4.4                3.2           1.3          0.2
# 43           5.0                3.5           1.6          0.6
# 44           5.1                3.8           1.9          0.4
# 45           4.8                3.0           1.4          0.3
# 46           5.1                3.8           1.6          0.2
# 47           4.6                3.2           1.4          0.2
# 48           5.3                3.7           1.5          0.2
# 49           5.0                3.3           1.4          0.2

# %%
df_class1.mean()
# Out:
# sepal_length         5.006
# sepal width in cm    3.418
# petal length         1.464
# petal width          0.244
# dtype: float64

# %%
df_class1.std()
# Out:
# sepal_length         0.352490
# sepal width in cm    0.381024
# petal length         0.173511
# petal width          0.107210
# dtype: float64

# %%
df_class1.mode()
# Out:
#    sepal_length  sepal width in cm  petal length  petal width
# 0           5.0                3.4           1.5          0.2
# 1           5.1                NaN           NaN          NaN

# %%
df_class2 = df.loc[df["class"] == "Iris-versicolor"]

# %%
df_class2
# Out:
#     sepal_length  sepal width in cm  petal length  petal width  \
# 50           7.0                3.2           4.7          1.4
# 51           6.4                3.2           4.5          1.5
# 52           6.9                3.1           4.9          1.5
# 53           5.5                2.3           4.0          1.3
# 54           6.5                2.8           4.6          1.5
# 55           5.7                2.8           4.5          1.3
# 56           6.3                3.3           4.7          1.6
# 57           4.9                2.4           3.3          1.0
# 58           6.6                2.9           4.6          1.3
# 59           5.2                2.7           3.9          1.4
# 60           5.0                2.0           3.5          1.0
# 61           5.9                3.0           4.2          1.5
# 62           6.0                2.2           4.0          1.0
# 63           6.1                2.9           4.7          1.4
# 64           5.6                2.9           3.6          1.3
# 65           6.7                3.1           4.4          1.4
# 66           5.6                3.0           4.5          1.5
# 67           5.8                2.7           4.1          1.0
# 68           6.2                2.2           4.5          1.5
# 69           5.6                2.5           3.9          1.1
# 70           5.9                3.2           4.8          1.8
# 71           6.1                2.8           4.0          1.3
# 72           6.3                2.5           4.9          1.5
# 73           6.1                2.8           4.7          1.2
# 74           6.4                2.9           4.3          1.3
# 75           6.6                3.0           4.4          1.4
# 76           6.8                2.8           4.8          1.4
# 77           6.7                3.0           5.0          1.7
# 78           6.0                2.9           4.5          1.5
# 79           5.7                2.6           3.5          1.0
# 80           5.5                2.4           3.8          1.1
# 81           5.5                2.4           3.7          1.0
# 82           5.8                2.7           3.9          1.2
# 83           6.0                2.7           5.1          1.6
# 84           5.4                3.0           4.5          1.5
# 85           6.0                3.4           4.5          1.6
# 86           6.7                3.1           4.7          1.5
# 87           6.3                2.3           4.4          1.3
# 88           5.6                3.0           4.1          1.3
# 89           5.5                2.5           4.0          1.3
# 90           5.5                2.6           4.4          1.2
# 91           6.1                3.0           4.6          1.4
# 92           5.8                2.6           4.0          1.2
# 93           5.0                2.3           3.3          1.0
# 94           5.6                2.7           4.2          1.3
# 95           5.7                3.0           4.2          1.2
# 96           5.7                2.9           4.2          1.3
# 97           6.2                2.9           4.3          1.3
# 98           5.1                2.5           3.0          1.1
# 99           5.7                2.8           4.1          1.3
#
#               class
# 50  Iris-versicolor
# 51  Iris-versicolor
# 52  Iris-versicolor
# 53  Iris-versicolor
# 54  Iris-versicolor
# 55  Iris-versicolor
# 56  Iris-versicolor
# 57  Iris-versicolor
# 58  Iris-versicolor
# 59  Iris-versicolor
# 60  Iris-versicolor
# 61  Iris-versicolor
# 62  Iris-versicolor
# 63  Iris-versicolor
# 64  Iris-versicolor
# 65  Iris-versicolor
# 66  Iris-versicolor
# 67  Iris-versicolor
# 68  Iris-versicolor
# 69  Iris-versicolor
# 70  Iris-versicolor
# 71  Iris-versicolor
# 72  Iris-versicolor
# 73  Iris-versicolor
# 74  Iris-versicolor
# 75  Iris-versicolor
# 76  Iris-versicolor
# 77  Iris-versicolor
# 78  Iris-versicolor
# 79  Iris-versicolor
# 80  Iris-versicolor
# 81  Iris-versicolor
# 82  Iris-versicolor
# 83  Iris-versicolor
# 84  Iris-versicolor
# 85  Iris-versicolor
# 86  Iris-versicolor
# 87  Iris-versicolor
# 88  Iris-versicolor
# 89  Iris-versicolor
# 90  Iris-versicolor
# 91  Iris-versicolor
# 92  Iris-versicolor
# 93  Iris-versicolor
# 94  Iris-versicolor
# 95  Iris-versicolor
# 96  Iris-versicolor
# 97  Iris-versicolor
# 98  Iris-versicolor
# 99  Iris-versicolor

# %%
df_class2 = df_class2.loc[:, df_class2.columns != "class"]

# %%
df_class2.std()
# Out:
# sepal_length         0.516171
# sepal width in cm    0.313798
# petal length         0.469911
# petal width          0.197753
# dtype: float64

# %%
df_class2.mean()
# Out:
# sepal_length         5.936
# sepal width in cm    2.770
# petal length         4.260
# petal width          1.326
# dtype: float64

# %%
df_class2.mode()
# Out:
#    sepal_length  sepal width in cm  petal length  petal width
# 0           5.5                3.0           4.5          1.3
# 1           5.6                NaN           NaN          NaN
# 2           5.7                NaN           NaN          NaN

# %%
df_class3 = df.loc[df["class"] == "Iris-virginica"]

# %%
df_class3 = df_class3.loc[:, df_class3.columns != "class"]

# %%
df_class3.mean()
# Out:
# sepal_length         6.588
# sepal width in cm    2.974
# petal length         5.552
# petal width          2.026
# dtype: float64

# %%
df_class3.std()
# Out:
# sepal_length         0.635880
# sepal width in cm    0.322497
# petal length         0.551895
# petal width          0.274650
# dtype: float64

# %%
df_class3.mode()
# Out:
#    sepal_length  sepal width in cm  petal length  petal width
# 0           6.3                3.0           5.1          1.8

# %%
df1.corr()
# Out:
#                    sepal_length  sepal width in cm  petal length  petal width
# sepal_length           1.000000          -0.109369      0.871754     0.817954
# sepal width in cm     -0.109369           1.000000     -0.420516    -0.356544
# petal length           0.871754          -0.420516      1.000000     0.962757
# petal width            0.817954          -0.356544      0.962757     1.000000

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sepal_width'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 plt.scatter(df[df['class'] == 'Iris-setosa']['sepal_length'], df[df['class'] == 'Iris-setosa']['sepal_width'], label='Iris-setosa')
#       2 plt.scatter(df[df['class'] == 'Iris-versicolor']['sepal_length'], df[df['class'] == 'Iris-versicolor']['sepal_width'], label='Iris-versicolor')
#       3 plt.scatter(df[df['class'] == 'Iris-virginica']['sepal_length'], df[df['class'] == 'Iris-virginica']['sepal_width'], label='Iris-virginica')
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File ~/anaconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'sepal_width'
